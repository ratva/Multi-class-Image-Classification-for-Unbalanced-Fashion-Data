# %% [markdown]
# # HW4 Trees and Forests
#
# Official instructions:
#
# https://www.cs.tufts.edu/cs/135/2023f/hw4.html
#
# This is the *starter code* notebook for Problems 1 and 2, looking at sentiment classification using bag-of-words features of product reviews.

# %%
import numpy as np
import pandas as pd
import os
import sys
import time
from random import shuffle

# %%
import sklearn.tree
import sklearn.linear_model
import sklearn.metrics
import sklearn.ensemble

# %%
# From the HW4 starter code
from pretty_print_sklearn_tree import pretty_print_sklearn_tree

# %%
# Plotting utils
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# # Load all data from train/valid/test

# %%
# TODO fix to path on your local system
DATA_DIR = os.path.join("data_product_reviews/")

# %% [markdown]
# ### Load training

# %%
x_tr_df = pd.read_csv(os.path.join(DATA_DIR, 'x_train.csv.zip'))
y_tr_df = pd.read_csv(os.path.join(DATA_DIR, 'y_train.csv'))
x_tr_NF = np.minimum(x_tr_df.values, 1.0).copy()
y_tr_N = y_tr_df.values[:,0].copy()

print("Training data")
print("x_tr_NF.shape: %s" % str(x_tr_NF.shape))
print("y_tr_N.shape : %s" % str(y_tr_N.shape))
print("mean(y_tr_N) : %.3f" % np.mean(y_tr_N))
# Out:
# Training data
# x_tr_NF.shape: (6346, 7729)
# y_tr_N.shape : (6346,)
# mean(y_tr_N) : 0.500

# %% [markdown]
# ### Load validation set

# %%
x_va_df = pd.read_csv(os.path.join(DATA_DIR, 'x_valid.csv.zip'))
y_va_df = pd.read_csv(os.path.join(DATA_DIR, 'y_valid.csv'))

x_va_TF = np.minimum(x_va_df.values, 1.0).copy()
y_va_T = y_va_df.values[:,0].copy()

print("Validation data")
print("x_va_TF.shape: %s" % str(x_va_TF.shape))
print("y_va_T.shape : %s" % str(y_va_T.shape))
print("mean(y_va_T) : %.3f" % np.mean(y_va_T))
# Out:
# Validation data
# x_va_TF.shape: (792, 7729)
# y_va_T.shape : (792,)
# mean(y_va_T) : 0.490

# %% [markdown]
# ### Load test set

# %%
x_te_df = pd.read_csv(os.path.join(DATA_DIR, 'x_test.csv.zip'))
y_te_df = pd.read_csv(os.path.join(DATA_DIR, 'y_test.csv'))

x_te_TF = np.minimum(x_te_df.values, 1.0).copy()
y_te_T = y_te_df.values[:,0].copy()

print("Heldout Test data")
print("x_te_TF.shape: %s" % str(x_te_TF.shape))
print("y_te_T.shape : %s" % str(y_te_T.shape))
print("mean(y_te_T) : %.3f" % np.mean(y_te_T))
# Out:
# Heldout Test data
# x_te_TF.shape: (793, 7729)
# y_te_T.shape : (793,)
# mean(y_te_T) : 0.515

# %% [markdown]
# ### Load vocabulary as a list of strings

# %%
vocab_list = x_tr_df.columns.tolist()

# %%
for word in vocab_list[:8]:
    print(word)
print("...")
for word in vocab_list[-8:]:
    print(word)
# Out:
# good
# great
# time
# book
# don't
# work
# i_have
# read
# ...
# never_get
# i'd_like
# loves_it
# an_author
# nomin
# could_give
# bad_but
# gap

# %% [markdown]
# ### Pack training and validation sets into big arrays (so we can use sklearn's hyperparameter search tools)

# %%
xall_LF = np.vstack([x_tr_NF, x_va_TF])
yall_L = np.hstack([y_tr_N, y_va_T])

# %%
valid_indicators_L = np.hstack([
    -1 * np.ones(y_tr_N.size), # -1 means never include this example in any test split
    0  * np.ones(y_va_T.size), #  0 means include in the first test split (we count starting at 0 in python)
    ])

# %%
# Create splitter object using Predefined Split
# Will be used later by all hyperparameter searches

my_splitter = sklearn.model_selection.PredefinedSplit(valid_indicators_L)

# %% [markdown]
# # Problem 1: Decision Trees
#
# ## 1A: Train a simple tree with depth 3

# %%
simple_tree = sklearn.tree.DecisionTreeClassifier(
    criterion='gini', 
    max_depth=3, min_samples_split=2, min_samples_leaf=1, 
    random_state=101)

# simple_tree_random = sklearn.tree.DecisionTreeClassifier(
#     criterion='gini', 
#     max_depth=3, min_samples_split=2, min_samples_leaf=1, 
#     random_state=101, splitter = 'random')

# simple_tree_best = sklearn.tree.DecisionTreeClassifier(
#     criterion='gini', 
#     max_depth=3, min_samples_split=2, min_samples_leaf=1, 
#     random_state=101, splitter = 'best')

# %% [markdown]
# ### **Fit the tree**
#
# **TODO Train on the training set** in the next coding cell

# %%
simple_tree.fit(x_tr_NF, y_tr_N)

# simple_tree_random.fit(x_tr_NF, y_tr_N)

# simple_tree_best.fit(x_tr_NF, y_tr_N)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=101)

# %% [markdown]
# ### **Figure 1: Print Tree**
#
# Use a helper function from the starter code

# %%
# Call pretty_print_sklearn_tree on simple_tree, providing feature_names=vocab_list
pretty_print_sklearn_tree(simple_tree, feature_names=vocab_list)

# pretty_print_sklearn_tree(simple_tree_random, feature_names=vocab_list)

# pretty_print_sklearn_tree(simple_tree_best, feature_names=vocab_list)
# Out:
# The binary tree structure has 15 nodes.
# - depth   0 has    1 nodes, of which    0 are leaves
# - depth   1 has    2 nodes, of which    0 are leaves
# - depth   2 has    4 nodes, of which    0 are leaves
# - depth   3 has    8 nodes, of which    8 are leaves
# The decision tree:  (Note: Y = 'yes' to above question; N = 'no')
# Decision: X['great'] <= 0.50?
#   Y Decision: X['excel'] <= 0.50?
#     Y Decision: X['disappoint'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.430 (4041 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.114 (368 total training examples)
#     N Decision: X['disappoint'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.903 (277 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.429 (14 total training examples)
#   N Decision: X['return'] <= 0.50?
#     Y Decision: X['bad'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.745 (1413 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.415 (142 total training examples)
#     N Decision: X['movie'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.190 (79 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.833 (12 total training examples)

# %% [markdown]
# ## 1B : Find best Decision Tree with grid search

# %%
# Construct the default predictor
# Any hyperparameters here may be overridden by the hyperparameter grid

base_tree = sklearn.tree.DecisionTreeClassifier(
    criterion='gini',
    min_samples_split=2, min_samples_leaf=1)

# %%
tree_hyperparameter_grid_by_name = dict(
    max_depth=[2, 8, 32, 128],
    min_samples_leaf=[1, 3, 9],
    random_state = [101],
    )

# %% [markdown]
# **TODO Build the Grid Search** in the next coding cell
#
# Follow the 1B instructions carefully

# %%
# Use grid search for tree classifier
tree_grid_searcher = sklearn.model_selection.GridSearchCV(estimator=base_tree, param_grid=tree_hyperparameter_grid_by_name,scoring='balanced_accuracy',cv=my_splitter, return_train_score=True, refit=False)

# %% [markdown]
# ### Do the search!

# %%
start_time_sec = time.time()
tree_grid_searcher.fit(xall_LF, yall_L)
elapsed_time_sec = time.time() - start_time_sec

# %% [markdown]
# ### Build dataframe of results
#
# Move the results of grid search into a nice pandas data frame.

# %%
if hasattr(tree_grid_searcher, 'cv_results_'):
    # Will be here if you called fit on tree_grid_searcher succesfully
    tree_search_results_df = pd.DataFrame(tree_grid_searcher.cv_results_).copy()
    print("Grid search of %3d configurations done after %6.1f sec" % (
        tree_search_results_df.shape[0], elapsed_time_sec))
# Out:
# Grid search of  12 configurations done after   81.0 sec

# %% [markdown]
# ### Display search results
#
# This block will make a pretty printed table of the results of your grid search

# %%
if hasattr(tree_grid_searcher, 'cv_results_'):
    pd.set_option('display.precision', 4)
    tree_keys = ['param_max_depth', 'param_min_samples_leaf']
    tree_search_results_df.sort_values(tree_keys, inplace=True)
    display(tree_search_results_df[tree_keys + ['mean_train_score', 'mean_test_score', 'rank_test_score', 'mean_fit_time']])
# Out:
#    param_max_depth param_min_samples_leaf  mean_train_score  mean_test_score  \
# 0                2                      1            0.6404           0.6339
# 1                2                      3            0.6404           0.6339
# 2                2                      9            0.6404           0.6339
# 3                8                      1            0.7279           0.6989
# 4                8                      3            0.7232           0.6978
# 5                8                      9            0.7123           0.6962
# 6               32                      1            0.9187           0.7325
# 7               32                      3            0.8752           0.7349
# 8               32                      9            0.8121           0.7197
# 9              128                      1            0.9981           0.7366
# 10             128                      3            0.9255           0.7274
# 11             128                      9            0.8308           0.7296
#
#     rank_test_score  mean_fit_time
# 0                10         1.5089
# 1                10         1.4426
# 2                10         1.2823
# 3                 7         3.7573
# 4                 8         3.6614
# 5                 9         3.7118
# 6                 3         9.4431
# 7                 2         9.0529
# 8                 6         8.4080
# 9                 1        14.7607
# 10                5        12.9207
# 11                4         9.7298

# %%
print("Printing a dict of the best hyperparameters")
try:
    print(tree_grid_searcher.best_params_)
except AttributeError:
    print("TODO")
# Out:
# Printing a dict of the best hyperparameters
# {'max_depth': 128, 'min_samples_leaf': 1, 'random_state': 101}

# %% [markdown]
# ### Build the best decision tree

# %% [markdown]
# **TODO Build the Best Tree on the training set** in the next coding cell
#
# This is necessary so you have the specific best performing tree in your workspace.
#
# Although you fit many trees in the search, they were not stored, so we need to recreate the best one.
#
# Hint: Just feed the best hyperparameters as keyword args to construct the tree and fit it to the training data.

# %%
# best_tree = base_tree 

best_tree = sklearn.tree.DecisionTreeClassifier(
    criterion='gini', max_depth = 128, min_samples_split=2, min_samples_leaf=1)
# Call set_params using the best_params_ found by your searcher
best_tree.fit(x_tr_NF, y_tr_N)
# Out:
# DecisionTreeClassifier(max_depth=128)

# %% [markdown]
# ### Interpret the best decision tree

# %%
pretty_print_sklearn_tree(best_tree, feature_names=vocab_list)
# Out:
# The binary tree structure has 1537 nodes.
# - depth   0 has    1 nodes, of which    0 are leaves
# - depth   1 has    2 nodes, of which    0 are leaves
# - depth   2 has    4 nodes, of which    0 are leaves
# - depth   3 has    8 nodes, of which    0 are leaves
# - depth   4 has   16 nodes, of which    5 are leaves
# - depth   5 has   22 nodes, of which    6 are leaves
# - depth   6 has   32 nodes, of which   13 are leaves
# - depth   7 has   38 nodes, of which   21 are leaves
# - depth   8 has   34 nodes, of which   16 are leaves
# - depth   9 has   36 nodes, of which   14 are leaves
# - depth  10 has   44 nodes, of which   21 are leaves
# - depth  11 has   46 nodes, of which   26 are leaves
# - depth  12 has   40 nodes, of which   17 are leaves
# - depth  13 has   46 nodes, of which   25 are leaves
# - depth  14 has   42 nodes, of which   25 are leaves
# - depth  15 has   34 nodes, of which   17 are leaves
# - depth  16 has   34 nodes, of which   16 are leaves
# - depth  17 has   36 nodes, of which   18 are leaves
# - depth  18 has   36 nodes, of which   21 are leaves
# - depth  19 has   30 nodes, of which   12 are leaves
# - depth  20 has   36 nodes, of which   17 are leaves
# - depth  21 has   38 nodes, of which   17 are leaves
# - depth  22 has   42 nodes, of which   22 are leaves
# - depth  23 has   40 nodes, of which   21 are leaves
# - depth  24 has   38 nodes, of which   22 are leaves
# - depth  25 has   32 nodes, of which   18 are leaves
# - depth  26 has   28 nodes, of which   15 are leaves
# - depth  27 has   26 nodes, of which   16 are leaves
# - depth  28 has   20 nodes, of which    9 are leaves
# - depth  29 has   22 nodes, of which   10 are leaves
# - depth  30 has   24 nodes, of which   16 are leaves
# - depth  31 has   16 nodes, of which   10 are leaves
# - depth  32 has   12 nodes, of which    6 are leaves
# - depth  33 has   12 nodes, of which    7 are leaves
# - depth  34 has   10 nodes, of which    2 are leaves
# - depth  35 has   16 nodes, of which    8 are leaves
# - depth  36 has   16 nodes, of which    9 are leaves
# - depth  37 has   14 nodes, of which    7 are leaves
# - depth  38 has   14 nodes, of which    8 are leaves
# - depth  39 has   12 nodes, of which    6 are leaves
# - depth  40 has   12 nodes, of which    7 are leaves
# - depth  41 has   10 nodes, of which    3 are leaves
# - depth  42 has   14 nodes, of which    6 are leaves
# - depth  43 has   16 nodes, of which    7 are leaves
# - depth  44 has   18 nodes, of which    9 are leaves
# - depth  45 has   18 nodes, of which    7 are leaves
# - depth  46 has   22 nodes, of which   15 are leaves
# - depth  47 has   14 nodes, of which    7 are leaves
# - depth  48 has   14 nodes, of which    8 are leaves
# - depth  49 has   12 nodes, of which    7 are leaves
# - depth  50 has   10 nodes, of which    6 are leaves
# - depth  51 has    8 nodes, of which    4 are leaves
# - depth  52 has    8 nodes, of which    4 are leaves
# - depth  53 has    8 nodes, of which    5 are leaves
# - depth  54 has    6 nodes, of which    3 are leaves
# - depth  55 has    6 nodes, of which    3 are leaves
# - depth  56 has    6 nodes, of which    3 are leaves
# - depth  57 has    6 nodes, of which    3 are leaves
# - depth  58 has    6 nodes, of which    4 are leaves
# - depth  59 has    4 nodes, of which    2 are leaves
# - depth  60 has    4 nodes, of which    2 are leaves
# - depth  61 has    4 nodes, of which    2 are leaves
# - depth  62 has    4 nodes, of which    1 are leaves
# - depth  63 has    6 nodes, of which    3 are leaves
# - depth  64 has    6 nodes, of which    3 are leaves
# - depth  65 has    6 nodes, of which    3 are leaves
# - depth  66 has    6 nodes, of which    4 are leaves
# - depth  67 has    4 nodes, of which    1 are leaves
# - depth  68 has    6 nodes, of which    3 are leaves
# - depth  69 has    6 nodes, of which    3 are leaves
# - depth  70 has    6 nodes, of which    3 are leaves
# - depth  71 has    6 nodes, of which    4 are leaves
# - depth  72 has    4 nodes, of which    1 are leaves
# - depth  73 has    6 nodes, of which    3 are leaves
# - depth  74 has    6 nodes, of which    3 are leaves
# - depth  75 has    6 nodes, of which    3 are leaves
# - depth  76 has    6 nodes, of which    3 are leaves
# - depth  77 has    6 nodes, of which    3 are leaves
# - depth  78 has    6 nodes, of which    3 are leaves
# - depth  79 has    6 nodes, of which    3 are leaves
# - depth  80 has    6 nodes, of which    3 are leaves
# - depth  81 has    6 nodes, of which    3 are leaves
# - depth  82 has    6 nodes, of which    3 are leaves
# - depth  83 has    6 nodes, of which    3 are leaves
# - depth  84 has    6 nodes, of which    3 are leaves
# - depth  85 has    6 nodes, of which    3 are leaves
# - depth  86 has    6 nodes, of which    2 are leaves
# - depth  87 has    8 nodes, of which    6 are leaves
# - depth  88 has    4 nodes, of which    3 are leaves
# - depth  89 has    2 nodes, of which    0 are leaves
# - depth  90 has    4 nodes, of which    2 are leaves
# - depth  91 has    4 nodes, of which    2 are leaves
# - depth  92 has    4 nodes, of which    2 are leaves
# - depth  93 has    4 nodes, of which    2 are leaves
# - depth  94 has    4 nodes, of which    2 are leaves
# - depth  95 has    4 nodes, of which    2 are leaves
# - depth  96 has    4 nodes, of which    2 are leaves
# - depth  97 has    4 nodes, of which    2 are leaves
# - depth  98 has    4 nodes, of which    2 are leaves
# - depth  99 has    4 nodes, of which    2 are leaves
# - depth 100 has    4 nodes, of which    2 are leaves
# - depth 101 has    4 nodes, of which    2 are leaves
# - depth 102 has    4 nodes, of which    3 are leaves
# - depth 103 has    2 nodes, of which    1 are leaves
# - depth 104 has    2 nodes, of which    1 are leaves
# - depth 105 has    2 nodes, of which    1 are leaves
# - depth 106 has    2 nodes, of which    1 are leaves
# - depth 107 has    2 nodes, of which    1 are leaves
# - depth 108 has    2 nodes, of which    1 are leaves
# - depth 109 has    2 nodes, of which    1 are leaves
# - depth 110 has    2 nodes, of which    1 are leaves
# - depth 111 has    2 nodes, of which    1 are leaves
# - depth 112 has    2 nodes, of which    1 are leaves
# - depth 113 has    2 nodes, of which    1 are leaves
# - depth 114 has    2 nodes, of which    1 are leaves
# - depth 115 has    2 nodes, of which    1 are leaves
# - depth 116 has    2 nodes, of which    1 are leaves
# - depth 117 has    2 nodes, of which    1 are leaves
# - depth 118 has    2 nodes, of which    1 are leaves
# - depth 119 has    2 nodes, of which    1 are leaves
# - depth 120 has    2 nodes, of which    1 are leaves
# - depth 121 has    2 nodes, of which    1 are leaves
# - depth 122 has    2 nodes, of which    1 are leaves
# - depth 123 has    2 nodes, of which    1 are leaves
# - depth 124 has    2 nodes, of which    1 are leaves
# - depth 125 has    2 nodes, of which    1 are leaves
# - depth 126 has    2 nodes, of which    1 are leaves
# - depth 127 has    2 nodes, of which    1 are leaves
# - depth 128 has    2 nodes, of which    2 are leaves
# The decision tree:  (Note: Y = 'yes' to above question; N = 'no')
# Decision: X['great'] <= 0.50?
#   Y Decision: X['excel'] <= 0.50?
#     Y Decision: X['disappoint'] <= 0.50?
#       Y Decision: X['easy'] <= 0.50?
#         Y Decision: X['love'] <= 0.50?
#           Y Decision: X['waste'] <= 0.50?
#             Y Decision: X['bad'] <= 0.50?
#               Y Decision: X['poor'] <= 0.50?
#                 Y Decision: X['the_best'] <= 0.50?
#                   Y Decision: X['return'] <= 0.50?
#                     Y Decision: X['perfect'] <= 0.50?
#                       Y Decision: X['worst'] <= 0.50?
#                         Y Decision: X['bore'] <= 0.50?
#                           Y Decision: X['enjoy'] <= 0.50?
#                             Y Decision: X['a_must'] <= 0.50?
#                               Y Decision: X['highly_recommend'] <= 0.50?
#                                 Y Decision: X['amaz'] <= 0.50?
#                                   Y Decision: X['good'] <= 0.50?
#                                     Y Decision: X['loved'] <= 0.50?
#                                       Y Decision: X['beauti'] <= 0.50?
#                                         Y Decision: X['of_our'] <= 0.50?
#                                           Y Decision: X['back'] <= 0.50?
#                                             Y Decision: X['fantast'] <= 0.50?
#                                               Y Decision: X['univers'] <= 0.50?
#                                                 Y Decision: X['smooth'] <= 0.50?
#                                                   Y Decision: X['wonder'] <= 0.50?
#                                                     Y Decision: X['outstand'] <= 0.50?
#                                                       Y Decision: X['knowledg'] <= 0.50?
#                                                         Y Decision: X['well_worth'] <= 0.50?
#                                                           Y Decision: X['am_very'] <= 0.50?
#                                                             Y Decision: X['complex'] <= 0.50?
#                                                               Y Decision: X['work'] <= 0.50?
#                                                                 Y Decision: X['the_job'] <= 0.50?
#                                                                   Y Decision: X['when_i'] <= 0.50?
#                                                                     Y Decision: X['heart'] <= 0.50?
#                                                                       Y Decision: X['analysi'] <= 0.50?
#                                                                         Y Decision: X['works'] <= 0.50?
#                                                                           Y Decision: X['very_nice'] <= 0.50?
#                                                                             Y Decision: X['ways'] <= 0.50?
#                                                                               Y Decision: X['glad'] <= 0.50?
#                                                                                 Y Decision: X['be_used'] <= 0.50?
#                                                                                   Y Decision: X['entir'] <= 0.50?
#                                                                                     Y Decision: X['favorit'] <= 0.50?
#                                                                                       Y Decision: X['loves'] <= 0.50?
#                                                                                         Y Decision: X['comfort'] <= 0.50?
#                                                                                           Y Decision: X['brother'] <= 0.50?
#                                                                                             Y Decision: X['equip'] <= 0.50?
#                                                                                               Y Decision: X['study'] <= 0.50?
#                                                                                                 Y Decision: X['can_you'] <= 0.50?
#                                                                                                   Y Decision: X['just_want'] <= 0.50?
#                                                                                                     Y Decision: X['to_another'] <= 0.50?
#                                                                                                       Y Decision: X['thriller'] <= 0.50?
#                                                                                                         Y Decision: X['seen_it'] <= 0.50?
#                                                                                                           Y Decision: X['never_have'] <= 0.50?
#                                                                                                             Y Decision: X['partner'] <= 0.50?
#                                                                                                               Y Decision: X['foam'] <= 0.50?
#                                                                                                                 Y Decision: X['a_hard'] <= 0.50?
#                                                                                                                   Y Decision: X['trip'] <= 0.50?
#                                                                                                                     Y Decision: X['for_many'] <= 0.50?
#                                                                                                                       Y Decision: X['highly_recommended'] <= 0.50?
#                                                                                                                         Y Decision: X['deeper'] <= 0.50?
#                                                                                                                           Y Decision: X['book_for'] <= 0.50?
#                                                                                                                             Y Decision: X['who_are'] <= 0.50?
#                                                                                                                               Y Decision: X['satisfi'] <= 0.50?
#                                                                                                                                 Y Decision: X['woman'] <= 0.50?
#                                                                                                                                   Y Decision: X['chapter'] <= 0.50?
#                                                                                                                                     Y Decision: X['the_ones'] <= 0.50?
#                                                                                                                                       Y Decision: X['dvds'] <= 0.50?
#                                                                                                                                         Y Decision: X['the_next'] <= 0.50?
#                                                                                                                                           Y Decision: X['my_life'] <= 0.50?
#                                                                                                                                             Y Decision: X['short_of'] <= 0.50?
#                                                                                                                                               Y Decision: X['5'] <= 0.50?
#                                                                                                                                                 Y Decision: X['makes_the'] <= 0.50?
#                                                                                                                                                   Y Decision: X['forev'] <= 0.50?
#                                                                                                                                                     Y Decision: X['it_gives'] <= 0.50?
#                                                                                                                                                       Y Decision: X['and_your'] <= 0.50?
#                                                                                                                                                         Y Decision: X['for_several'] <= 0.50?
#                                                                                                                                                           Y Decision: X['valuabl'] <= 0.50?
#                                                                                                                                                             Y Decision: X['using_them'] <= 0.50?
#                                                                                                                                                               Y Decision: X['just_that'] <= 0.50?
#                                                                                                                                                                 Y Decision: X['even_more'] <= 0.50?
#                                                                                                                                                                   Y Decision: X['stun'] <= 0.50?
#                                                                                                                                                                     Y Decision: X['phone_and'] <= 0.50?
#                                                                                                                                                                       Y Decision: X['well_made'] <= 0.50?
#                                                                                                                                                                         Y Decision: X['the_center'] <= 0.50?
#                                                                                                                                                                           Y Decision: X['pleased_with'] <= 0.50?
#                                                                                                                                                                             Y Decision: X['my_review'] <= 0.50?
#                                                                                                                                                                               Y Decision: X['tool'] <= 0.50?
#                                                                                                                                                                                 Y Decision: X['success'] <= 0.50?
#                                                                                                                                                                                   Y Decision: X['intrigu'] <= 0.50?
#                                                                                                                                                                                     Y Decision: X['thrill'] <= 0.50?
#                                                                                                                                                                                       Y Decision: X['novic'] <= 0.50?
#                                                                                                                                                                                         Y Decision: X['product_for'] <= 0.50?
#                                                                                                                                                                                           Y Decision: X['deserv'] <= 0.50?
#                                                                                                                                                                                             Y Decision: X['grew'] <= 0.50?
#                                                                                                                                                                                               Y Decision: X['worth_reading'] <= 0.50?
#                                                                                                                                                                                                 Y Decision: X['link'] <= 0.50?
#                                                                                                                                                                                                   Y Decision: X['i_like'] <= 0.50?
#                                                                                                                                                                                                     Y Decision: X['was_able'] <= 0.50?
#                                                                                                                                                                                                       Y Decision: X['for_less'] <= 0.50?
#                                                                                                                                                                                                         Y Decision: X['i_say'] <= 0.50?
#                                                                                                                                                                                                           Y Decision: X['shelf'] <= 0.50?
#                                                                                                                                                                                                             Y Decision: X['just_about'] <= 0.50?
#                                                                                                                                                                                                               Y Decision: X['planet'] <= 0.50?
#                                                                                                                                                                                                                 Y Decision: X['no_problem'] <= 0.50?
#                                                                                                                                                                                                                   Y Decision: X['bought_my'] <= 0.50?
#                                                                                                                                                                                                                     Y Decision: X['for_all'] <= 0.50?
#                                                                                                                                                                                                                       Y Decision: X['was_wrong'] <= 0.50?
#                                                                                                                                                                                                                         Y Decision: X['cry'] <= 0.50?
#                                                                                                                                                                                                                           Y Decision: X['clock'] <= 0.50?
#                                                                                                                                                                                                                             Y Decision: X['winner'] <= 0.50?
#                                                                                                                                                                                                                               Y Decision: X['it_<num>'] <= 0.50?
#                                                                                                                                                                                                                                 Y Decision: X['can_go'] <= 0.50?
#                                                                                                                                                                                                                                   Y Decision: X['for_no'] <= 0.50?
#                                                                                                                                                                                                                                     Y Decision: X['inspir'] <= 0.50?
#                                                                                                                                                                                                                                       Y Decision: X['sophist'] <= 0.50?
#                                                                                                                                                                                                                                         Y Decision: X['stylish'] <= 0.50?
#                                                                                                                                                                                                                                           Y Decision: X['processor'] <= 0.50?
#                                                                                                                                                                                                                                             Y Decision: X['notebook'] <= 0.50?
#                                                                                                                                                                                                                                               Y Decision: X['my_friends'] <= 0.50?
#                                                                                                                                                                                                                                                 Y Decision: X['just_got'] <= 0.50?
#                                                                                                                                                                                                                                                   Y Decision: X['special_features'] <= 0.50?
#                                                                                                                                                                                                                                                     Y Decision: X['countless'] <= 0.50?
#                                                                                                                                                                                                                                                       Y Decision: X['they_get'] <= 0.50?
#                                                                                                                                                                                                                                                         Y Decision: X['old_and'] <= 0.50?
#                                                                                                                                                                                                                                                           Y Decision: X['<num>_<year>'] <= 0.50?
#                                                                                                                                                                                                                                                             Y Decision: X['found_myself'] <= 0.50?
#                                                                                                                                                                                                                                                               Y Decision: X['in_both'] <= 0.50?
#                                                                                                                                                                                                                                                                 Y Leaf: p(y=1 | this leaf) = 0.054 (557 total training examples)
#                                                                                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                                                                                                                                                           N Decision: X['grind'] <= 0.50?
#                                                                                                                                                                                                             Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                         N Decision: X['steel'] <= 0.50?
#                                                                                                                                                                                                           Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                       N Decision: X['damag'] <= 0.50?
#                                                                                                                                                                                                         Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                     N Decision: X['gave'] <= 0.50?
#                                                                                                                                                                                                       Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                                                                                                                                                                                                   N Decision: X['wait'] <= 0.50?
#                                                                                                                                                                                                     Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                                 N Decision: X['author'] <= 0.50?
#                                                                                                                                                                                                   Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                               N Decision: X['less_than'] <= 0.50?
#                                                                                                                                                                                                 Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                             N Decision: X['space'] <= 0.50?
#                                                                                                                                                                                               Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                           N Decision: X['i'm'] <= 0.50?
#                                                                                                                                                                                             Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                         N Decision: X['written'] <= 0.50?
#                                                                                                                                                                                           Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                                       N Decision: X['of_his'] <= 0.50?
#                                                                                                                                                                                         Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                                                                                                                                                                                     N Decision: X['found'] <= 0.50?
#                                                                                                                                                                                       Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                                                                                                                                                                                   N Decision: X['found'] <= 0.50?
#                                                                                                                                                                                     Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                             N Decision: X['as_long'] <= 0.50?
#                                                                                                                                                                               Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
# ...
#                                                         Y Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                     N Decision: X['leav'] <= 0.50?
#                                                       Y Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                               N Decision: X['belkin'] <= 0.50?
#                                                 Y Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                             N Decision: X['charact'] <= 0.50?
#                                               Y Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#                                               N Decision: X['execut'] <= 0.50?
#                                                 Y Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                         N Decision: X['the_first'] <= 0.50?
#                                           Y Decision: X['continu'] <= 0.50?
#                                             Y Decision: X['seri'] <= 0.50?
#                                               Y Decision: X['to_see'] <= 0.50?
#                                                 Y Leaf: p(y=1 | this leaf) = 1.000 (15 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#                                       N Decision: X['and_i'] <= 0.50?
#                                         Y Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#                                         N Decision: X['the_table'] <= 0.50?
#                                           Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                     N Decision: X['charg'] <= 0.50?
#                                       Y Decision: X['coupl'] <= 0.50?
#                                         Y Decision: X['love'] <= 0.50?
#                                           Y Leaf: p(y=1 | this leaf) = 0.000 (8 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#                                   N Decision: X['wit'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.000 (6 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                                 N Decision: X['screen'] <= 0.50?
#                                   Y Decision: X['compared_to'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.000 (7 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                               N Decision: X['for_your'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 0.000 (7 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#                           N Decision: X['high'] <= 0.50?
#                             Y Decision: X['than_this'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                         N Decision: X['you_don't'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.000 (8 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                       N Decision: X['i've'] <= 0.50?
#                         Y Decision: X['don't'] <= 0.50?
#                           Y Decision: X['an_excellent'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 0.000 (15 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                           N Decision: X['is_not'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 1.000 (7 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (5 total training examples)
#                     N Decision: X['his_wife'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 0.000 (10 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                   N Decision: X['a_good'] <= 0.50?
#                     Y Decision: X['because_i'] <= 0.50?
#                       Y Decision: X['pull'] <= 0.50?
#                         Y Decision: X['to_help'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.000 (16 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                     N Decision: X['role'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 1.000 (5 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                 N Decision: X['day'] <= 0.50?
#                   Y Decision: X['it_because'] <= 0.50?
#                     Y Decision: X['night'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 0.000 (14 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (8 total training examples)
#             N Decision: X['years'] <= 0.50?
#               Y Decision: X['cook'] <= 0.50?
#                 Y Decision: X['purchas'] <= 0.50?
#                   Y Decision: X['gave_it'] <= 0.50?
#                     Y Decision: X['only_a'] <= 0.50?
#                       Y Decision: X['sound'] <= 0.50?
#                         Y Decision: X['appar'] <= 0.50?
#                           Y Decision: X['had_some'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 1.000 (20 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Decision: X['speaker'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                   N Decision: X['at_all'] <= 0.50?
#                     Y Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.000 (5 total training examples)
#               N Decision: X['casual'] <= 0.50?
#                 Y Leaf: p(y=1 | this leaf) = 0.000 (10 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#           N Decision: X['real'] <= 0.50?
#             Y Decision: X['best_of'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 0.000 (21 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#             N Decision: X['summari'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#         N Decision: X['be_disappointed'] <= 0.50?
#           Y Decision: X['was_not'] <= 0.50?
#             Y Decision: X['you'll'] <= 0.50?
#               Y Decision: X['excel'] <= 0.50?
#                 Y Decision: X['of_my'] <= 0.50?
#                   Y Decision: X['buy_it'] <= 0.50?
#                     Y Decision: X['to_see'] <= 0.50?
#                       Y Decision: X['work_in'] <= 0.50?
#                         Y Decision: X['cancel'] <= 0.50?
#                           Y Decision: X['pan'] <= 0.50?
#                             Y Decision: X['that_much'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 0.000 (44 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Decision: X['film_is'] <= 0.50?
#                         Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#             N Decision: X['earlier'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 1.000 (8 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#           N Decision: X['this_device'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#       N Decision: X['is_really'] <= 0.50?
#         Y Decision: X['run'] <= 0.50?
#           Y Decision: X['the_best'] <= 0.50?
#             Y Decision: X['dvd'] <= 0.50?
#               Y Decision: X['i_love'] <= 0.50?
#                 Y Decision: X['one_on'] <= 0.50?
#                   Y Decision: X['cook'] <= 0.50?
#                     Y Decision: X['provid'] <= 0.50?
#                       Y Decision: X['excel'] <= 0.50?
#                         Y Decision: X['cabl'] <= 0.50?
#                           Y Decision: X['works_great'] <= 0.50?
#                             Y Decision: X['what_makes'] <= 0.50?
#                               Y Decision: X['worth_the'] <= 0.50?
#                                 Y Decision: X['another_great'] <= 0.50?
#                                   Y Decision: X['batch'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.000 (70 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                           N Decision: X['people_are'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                     N Decision: X['stainless_steel'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (3 total training examples)
#                 N Decision: X['long'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 1.000 (7 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)
#               N Decision: X['period'] <= 0.50?
#                 Y Leaf: p(y=1 | this leaf) = 1.000 (6 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#             N Decision: X['based_on'] <= 0.50?
#               Y Decision: X['i_love'] <= 0.50?
#                 Y Leaf: p(y=1 | this leaf) = 1.000 (12 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.000 (3 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (4 total training examples)
#           N Decision: X['rememb'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#         N Leaf: p(y=1 | this leaf) = 1.000 (8 total training examples)
#     N Decision: X['movie'] <= 0.50?
#       Y Decision: X['learn'] <= 0.50?
#         Y Decision: X['man'] <= 0.50?
#           Y Decision: X['was_too'] <= 0.50?
#             Y Decision: X['than_that'] <= 0.50?
#               Y Decision: X['am_not'] <= 0.50?
#                 Y Decision: X['6'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 0.000 (62 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Decision: X['car'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#             N Leaf: p(y=1 | this leaf) = 1.000 (2 total training examples)
#           N Decision: X['string'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#         N Leaf: p(y=1 | this leaf) = 1.000 (4 total training examples)
#       N Decision: X['is_not'] <= 0.50?
#         Y Leaf: p(y=1 | this leaf) = 1.000 (10 total training examples)
#         N Leaf: p(y=1 | this leaf) = 0.000 (2 total training examples)

# %% [markdown]
# # Problem 2: Random forest

# %% [markdown]
# ## 2A: Train a random forest with default settings

# %%
simple_forest = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100,
    criterion='gini',
    max_features='sqrt',
    max_depth=3,
    min_samples_leaf=1,
    min_samples_split=2,
    random_state=101)

# %% [markdown]
# ### Fit the forest
#
# **TODO Train on the training set** in the next coding cell

# %%
# Call fit, like: `simple_forest.fit(None, None)`
simple_forest.fit(x_tr_NF, y_tr_N)
# Out:
# RandomForestClassifier(max_depth=3, random_state=101)

# %% [markdown]
# ## 2B & Table 2: Feature Importances

# %% [markdown]
# ### Table 2
# **Sample Output** (Feel free to print all words and organize them in any software)
#
# |**Important Words**|**Unimportant Words**|
# |:-:|:-:|
# |I1 |  U1  |
# |I2 |  U2  |
# |I3 |  U3  |
# |I4 |  U4  |
# |I5 |  U5  |
# |I6 |  U6  |
# |I7 |  U7  |
# |I8 |  U8  |
# |I9 |  U9  |
# |I0 |  U0  |

# %%
# Sort features by importance
importRating, featureName = list(zip(*sorted(zip(simple_forest.feature_importances_, vocab_list),reverse=True)))

# Display top 10 most important
simpleForestImportFeats = pd.DataFrame({'feature': featureName, 'importance': importRating})
display(simpleForestImportFeats[0:10])

# print(simpleForestImportFeats[0:10].style.to_latex())

lowImport = np.less(importRating,0.00001)

print('%i features available with importance < 0.00001' % lowImport.sum())

unimpFeats = np.array(featureName)[lowImport]
unimportRating = np.array(importRating)[lowImport]

# Display top 10 most important and 10 random unimportant features
simpleForestImportFeatsTop = pd.DataFrame({'Important Feature': featureName[0:10], 'Importance': importRating[0:10], 'Unimportant Feature': unimpFeats[47:7248:790], 'Importance ': unimportRating[47:7248:790]})
display(simpleForestImportFeatsTop)
# print(simpleForestImportFeatsTop.style.to_latex())
# Out:
#       feature  importance
# 0      return      0.0335
# 1       excel      0.0295
# 2       great      0.0293
# 3       worst      0.0284
# 4        poor      0.0269
# 5  disappoint      0.0244
# 6      i_love      0.0185
# 7  your_money      0.0180
# 8       don't      0.0176
# 9        bore      0.0164
# 7288 features available with importance < 0.00001
#   Important Feature  Importance Unimportant Feature  Importance
# 0            return      0.0335              you_in          0.0
# 1             excel      0.0295       to_understand          0.0
# 2             great      0.0293          the_answer          0.0
# 3             worst      0.0284           return_to          0.0
# 4              poor      0.0269        nothing_else          0.0
# 5        disappoint      0.0244               japan          0.0
# 6            i_love      0.0185         happened_to          0.0
# 7        your_money      0.0180           don't_see          0.0
# 8             don't      0.0176                bias          0.0
# 9              bore      0.0164             a_major          0.0

# %%
# REMOVE ZERO and Sort features by importance
importRating, featureName = list(zip(*sorted(zip(simple_forest.feature_importances_, vocab_list),reverse=True)))

# Display top 10 most important
simpleForestImportFeats = pd.DataFrame({'feature': featureName, 'importance': importRating})
display(simpleForestImportFeats[0:20])

# print(simpleForestImportFeats[0:10].style.to_latex())

lowImport = np.less(importRating,0.00001)

print('%i features available with importance < 0.00001' % lowImport.sum())

unimpFeats = np.array(featureName)[lowImport]
unimportRating = np.array(importRating)[lowImport]

# Display top 10 most important and 10 random unimportant features
simpleForestImportFeatsTop = pd.DataFrame({'Important Feature': featureName[0:10], 'Importance': importRating[0:10], 'Unimportant Feature': unimpFeats[47:7248:790], 'Importance ': unimportRating[47:7248:790]})
display(simpleForestImportFeatsTop)
# print(simpleForestImportFeatsTop.style.to_latex())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\avtar\OneDrive - Tufts\Tufts CS\CS135 Intro to ML\hw4\hw4_notebook.ipynb Cell 52 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/avtar/OneDrive%20-%20Tufts/Tufts%20CS/CS135%20Intro%20to%20ML/hw4/hw4_notebook.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> # REMOVE ZERO and Sort features by importance
# ----> <a href='vscode-notebook-cell:/c%3A/Users/avtar/OneDrive%20-%20Tufts/Tufts%20CS/CS135%20Intro%20to%20ML/hw4/hw4_notebook.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> importRating, featureName = list(zip(*sorted(zip(simple_forest.feature_importances_, vocab_list),reverse=True)))
#       <a href='vscode-notebook-cell:/c%3A/Users/avtar/OneDrive%20-%20Tufts/Tufts%20CS/CS135%20Intro%20to%20ML/hw4/hw4_notebook.ipynb#Y102sZmlsZQ%3D%3D?line=3'>4</a> # Display top 10 most important
#       <a href='vscode-notebook-cell:/c%3A/Users/avtar/OneDrive%20-%20Tufts/Tufts%20CS/CS135%20Intro%20to%20ML/hw4/hw4_notebook.ipynb#Y102sZmlsZQ%3D%3D?line=4'>5</a> simpleForestImportFeats = pd.DataFrame({'feature': featureName, 'importance': importRating})
#
# NameError: name 'simple_forest' is not defined

# %% [markdown]
# ## 2C: Best Random Forest via grid search
#
# Follow the instructions and using what you learn in 1B to finish this step.
#
# This block might take 2-10 minutes. (Takes about 2 min on staff Macbook laptops.)
#
# If yours runs significantly longer, try this out on Google Colab instead.

# %%
base_forest = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100,
    criterion='gini',
    max_depth=16,
    min_samples_split=2,
    min_samples_leaf=1)

# %%
forest_hyperparameter_grid_by_name = dict(
    max_features=[3, 10, 33, 100, 333],
    max_depth=[16, 32],
    min_samples_leaf=[1],
    n_estimators=[100],
    random_state=[101],
    )

# %%
# construct a GridSearchCV object like you did above.

forest_searcher = sklearn.model_selection.GridSearchCV(estimator=base_forest, param_grid=forest_hyperparameter_grid_by_name,scoring='balanced_accuracy',cv=my_splitter, return_train_score=True, refit=False)

# %% [markdown]
# ### Do the search!

# %%
start_time_sec = time.time()
forest_searcher.fit(xall_LF, yall_L)
elapsed_time_sec = time.time() - start_time_sec

# %% [markdown]
# ### Build dataframe of results

# %%
if hasattr(forest_searcher, 'cv_results_'):
    # Will be here if you called fit on forest_searcher succesfully
    forest_search_results_df = pd.DataFrame(forest_searcher.cv_results_).copy()
    print("Grid search of %3d configurations done after %6.1f sec" % (
        forest_search_results_df.shape[0], elapsed_time_sec))
# Out:
# Grid search of  10 configurations done after  104.8 sec

# %% [markdown]
# ### Display search results

# %%
if hasattr(forest_searcher, 'cv_results_'):
    pd.set_option('display.precision', 4)
    forest_keys = ['param_max_depth', 'param_max_features']
    forest_search_results_df.sort_values(forest_keys, inplace=True)
    display(forest_search_results_df[forest_keys + ['mean_train_score', 'mean_test_score', 'rank_test_score', 'mean_fit_time']])
# Out:
#   param_max_depth param_max_features  mean_train_score  mean_test_score  \
# 0              16                  3            0.9139           0.7490
# 1              16                 10            0.9294           0.8333
# 2              16                 33            0.9244           0.8462
# 3              16                100            0.9170           0.8342
# 4              16                333            0.8725           0.7854
# 5              32                  3            0.9762           0.7926
# 6              32                 10            0.9721           0.8471
# 7              32                 33            0.9690           0.8373
# 8              32                100            0.9677           0.8392
# 9              32                333            0.9540           0.8198
#
#    rank_test_score  mean_fit_time
# 0               10         0.5764
# 1                6         1.0477
# 2                2         2.5068
# 3                5         6.3941
# 4                9        19.1518
# 5                8         0.9039
# 6                1         1.8854
# 7                4         4.5884
# 8                3        15.8568
# 9                7        48.6250

# %% [markdown]
# ### Build the best random forest using the best hyperparameters found in 2B
#
# This is necessary so you have the specific best performing forest in your workspace.
#
# Train *only* on training set (do not merge train and valid)

# %%
print(forest_searcher.best_params_)

best_forest = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100, criterion='gini', max_depth=32, max_features=10, min_samples_leaf=1,random_state=101)

best_forest.fit(x_tr_NF, y_tr_N)
# Out:
# {'max_depth': 32, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 100, 'random_state': 101}
# RandomForestClassifier(max_depth=32, max_features=10, random_state=101)

# %%
# for tree in best_forest:
#     print(tree.max_depth)

print(len(vocab_list))
# Out:
# 7729

# %%
# Sort features by importance
importRating, featureName = zip(*sorted(zip(best_forest.feature_importances_, vocab_list),reverse=True))

# Display top 20 most important
bestImportFeats = pd.DataFrame({'feature': featureName, 'importance': importRating})
display(bestImportFeats[0:20])
print(bestImportFeats[0:20].style.to_latex())
# Out:
#          feature  importance
# 0          great      0.0075
# 1            bad      0.0059
# 2     disappoint      0.0057
# 3          excel      0.0057
# 4       waste_of      0.0055
# 5     your_money      0.0049
# 6           poor      0.0047
# 7           bore      0.0041
# 8         return      0.0041
# 9          worst      0.0039
# 10         waste      0.0038
# 11          easy      0.0036
# 12       perfect      0.0033
# 13       easy_to      0.0033
# 14        wonder      0.0032
# 15       horribl      0.0030
# 16     the_worst      0.0027
# 17      the_best      0.0027
# 18  an_excellent      0.0026
# 19          love      0.0025
# \begin{tabular}{llr}
#  & feature & importance \\
# 0 & great & 0.007526 \\
# 1 & bad & 0.005939 \\
# 2 & disappoint & 0.005716 \\
# 3 & excel & 0.005700 \\
# 4 & waste_of & 0.005503 \\
# 5 & your_money & 0.004885 \\
# 6 & poor & 0.004723 \\
# 7 & bore & 0.004114 \\
# 8 & return & 0.004061 \\
# 9 & worst & 0.003867 \\
# 10 & waste & 0.003833 \\
# 11 & easy & 0.003564 \\
# 12 & perfect & 0.003303 \\
# 13 & easy_to & 0.003267 \\
# 14 & wonder & 0.003171 \\
# 15 & horribl & 0.002967 \\
# 16 & the_worst & 0.002693 \\
# 17 & the_best & 0.002686 \\
# 18 & an_excellent & 0.002639 \\
# 19 & love & 0.002462 \\
# \end{tabular}

# %% [markdown]
# ### Table 3: Comparison of methods on the bag-of-words to sentiment classification task.
#
# Please report **balanced accuracy** on the train, valid, and test sets, to 3 digits of precision
#
# **Sample Output** (Feel free to print all values and organize them by hand)
#
# |**method**|**max depth**|**num trees**|**train BAcc**|**valid BAcc**|**test BAcc**|
# |:-|:-:|:-:|:-:|:-:|:-:|
# |simple Tree	| 1 | 1 | 0.123	|0.456	|0.890|
# |best Tree	|1 | 1 | 0.123	|0.456	|0.890|
# |simple RandomForest	|1 | 1 | 0.123	|0.456	|0.890|
# |best RandomForest	|1 | 1 | 0.123	|0.456	|0.890|

# %%
simpleTree_tr = sklearn.metrics.balanced_accuracy_score(y_tr_N, simple_tree.predict(x_tr_NF))
simpleTree_va = sklearn.metrics.balanced_accuracy_score(y_va_T, simple_tree.predict(x_va_TF))
simpleTree_te = sklearn.metrics.balanced_accuracy_score(y_te_T, simple_tree.predict(x_te_TF))


bestTree_tr = sklearn.metrics.balanced_accuracy_score(y_tr_N, best_tree.predict(x_tr_NF))
bestTree_va = sklearn.metrics.balanced_accuracy_score(y_va_T, best_tree.predict(x_va_TF))
bestTree_te = sklearn.metrics.balanced_accuracy_score(y_te_T, best_tree.predict(x_te_TF))


simpleForest_tr = sklearn.metrics.balanced_accuracy_score(y_tr_N, simple_forest.predict(x_tr_NF))
simpleForest_va = sklearn.metrics.balanced_accuracy_score(y_va_T, simple_forest.predict(x_va_TF))
simpleForest_te = sklearn.metrics.balanced_accuracy_score(y_te_T, simple_forest.predict(x_te_TF))


bestForest_tr = sklearn.metrics.balanced_accuracy_score(y_tr_N, best_forest.predict(x_tr_NF))
bestForest_va = sklearn.metrics.balanced_accuracy_score(y_va_T, best_forest.predict(x_va_TF))
bestForest_te = sklearn.metrics.balanced_accuracy_score(y_te_T, best_forest.predict(x_te_TF))

comparisonDF = pd.DataFrame({'Method': ['simple Tree','best Tree', 'simple RandomForest','best RandomForest'],'Max Depth': [3,128,3,32], 'num trees': [1,1,100,100],'Training': [simpleTree_tr,bestTree_tr,simpleForest_tr,bestForest_tr],'Validation': [simpleTree_va,bestTree_va,simpleForest_va,bestForest_va],'Test': [simpleTree_te,bestTree_te,simpleForest_te,bestForest_te]})

display(comparisonDF)
print(comparisonDF.style.to_latex())
# Out:
#                 Method  Max Depth  num trees  Training  Validation    Test
# 0          simple Tree          3          1    0.6458      0.6446  0.6458
# 1            best Tree        128          1    0.9965      0.7380  0.7413
# 2  simple RandomForest          3        100    0.8164      0.7971  0.7731
# 3    best RandomForest         32        100    0.9721      0.8471  0.8157
# \begin{tabular}{llrrrrr}
#  & Method & Max Depth & num trees & Training & Validation & Test \\
# 0 & simple Tree & 3 & 1 & 0.645773 & 0.644560 & 0.645849 \\
# 1 & best Tree & 128 & 1 & 0.996531 & 0.738045 & 0.741307 \\
# 2 & simple RandomForest & 3 & 100 & 0.816448 & 0.797119 & 0.773097 \\
# 3 & best RandomForest & 32 & 100 & 0.972117 & 0.847134 & 0.815661 \\
# \end{tabular}
